# %% [markdown]
# # IMPORT LIBRARY

# %%
import os 
import pandas as pd 
import matplotlib as plt

# %% [markdown]
# # ETL

# %% [markdown]
# Extract

# %%
Data = pd.DataFrame()
for i in os.listdir(os.getcwd()):
    if i.endswith('.csv'):
        Data = Data.append(pd.read_csv(i))
Data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# Transform

# %%
Data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %% [markdown]
# # DATA CLEANING & DATA MANIPULATION

# %%
Data.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
Data = Data.dropna()
Data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
Data['Order Date'].head()
# Out:
# 0    04/19/19 08:46
# 2    04/07/19 22:30
# 3    04/12/19 14:38
# 4    04/12/19 14:38
# 5    04/30/19 09:27
# Name: Order Date, dtype: object

# %%
Data['Order Date'] = pd.to_datetime(Data['Order Date'],format='%m/%d/%y %H:%M',errors = 'coerce')
Data
# Out:
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/254897764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Order Date'] = pd.to_datetime(Data['Order Date'],format='%m/%d/%y %H:%M',errors = 'coerce')
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# ...

# %%
Data['Street Number'] = Data['Purchase Address'].str.split(' ', n=1).str[0]
Data['Address'] = Data['Purchase Address'].str.split(' ', n=1).str[1]
Data.drop('Purchase Address',axis=1 , inplace=True)
Data
# Out:
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/1892461468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Street Number'] = Data['Purchase Address'].str.split(' ', n=1).str[0]
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/1892461468.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Address'] = Data['Purchase Address'].str.split(' ', n=1).str[1]
# C:\Users\MAHMOUD\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# ...

# %%
split_address = Data['Address'].str.split(',', expand=True)
Data['Street Name'] = split_address[0]
Data['City'] = split_address[1]
Data['State'] = split_address[2]
Data
# Out:
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/1305411780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Street Name'] = split_address[0]
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/1305411780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['City'] = split_address[1]
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/1305411780.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Data.drop('Address',axis=1,inplace=True)
# Out:
# C:\Users\MAHMOUD\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#                Order Date Street Number  Street Name            City  \
# ...

# %%
State = Data['State'].str.split(' ', expand=True)
Data.drop('State',axis=1,inplace=True)
# Out:
# C:\Users\MAHMOUD\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Data['State'] = State[1]
Data['Postal code'] = State[2]
Data
# Out:
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/3961158295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['State'] = State[1]
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/3961158295.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Postal code'] = State[2]
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# ...

# %%
Data['Quantity Ordered'] = Data['Quantity Ordered'].str.replace('[^\d.]', '', regex=True)
Data['Quantity Ordered'] = pd.to_numeric(Data['Quantity Ordered'], errors='coerce')
Data = Data.dropna(subset=['Quantity Ordered'])
Data['Price Each'] = Data['Price Each'].str.replace(' ', '', regex=True).astype(float)
Data.info()
# Out:
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/677488340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Quantity Ordered'] = Data['Quantity Ordered'].str.replace('[^\d.]', '', regex=True)
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/677488340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Quantity Ordered'] = pd.to_numeric(Data['Quantity Ordered'], errors='coerce')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 11685
# ...

# %%
Data['Total Price'] = Data['Quantity Ordered'] * Data['Price Each']
Data
# Out:
# C:\Users\MAHMOUD\AppData\Local\Temp/ipykernel_29676/1789763065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Total Price'] = Data['Quantity Ordered'] * Data['Price Each']
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable               2.0       11.95
# 2       176559  Bose SoundSport Headphones               1.0       99.99
# 3       176560                Google Phone               1.0      600.00
# 4       176560            Wired Headphones               1.0       11.99
# 5       176561            Wired Headphones               1.0       11.99
# ...        ...                         ...               ...         ...
# ...

# %% [markdown]
# Load

# %%
Data.to_csv('FullData.csv')
